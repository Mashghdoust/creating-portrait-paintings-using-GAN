# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

GENERATE_RES = 4 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 250

# Configuration
DATA_PATH = '/content/drive/MyDrive/Thesis/images'
EPOCHS = 100
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")

def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      if np.asarray(image).shape==(128,128,3):
        training_data.append(np.asarray(image))
  
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)

#shuffle the data
train_dataset = tf.data.Dataset.from_tensor_slices(training_data) \
    .shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)

cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'\
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

train(train_dataset, EPOCHS)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Will generate 128px square images.
# Looking for file: /content/drive/MyDrive/Thesis/images/training_data_128_128.npy
# Loading training images...
#  66%|██████▌   | 984/1496 [00:41<00:26, 19.69it/s]/usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# 100%|██████████| 1496/1496 [01:06<00:00, 22.64it/s]
# Saving training image binary...
# Image preprocess time: 0:01:07.03
# tf.Tensor([[0.49915954]], shape=(1, 1), dtype=float32)
# Epoch 1, gen loss=1.7637473344802856,disc loss=1.3283778429031372, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=3.7130277156829834,disc loss=1.1010221242904663, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=3.7471203804016113,disc loss=1.5627491474151611, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=3.7298712730407715,disc loss=1.0348691940307617, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=5.21783447265625,disc loss=1.186219573020935, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=4.379091262817383,disc loss=1.7963359355926514, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=4.272594451904297,disc loss=1.0455219745635986, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=3.5079169273376465,disc loss=1.2026487588882446, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=4.690143585205078,disc loss=1.0498923063278198, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=3.676077127456665,disc loss=1.3335590362548828, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=3.4635932445526123,disc loss=1.3425493240356445, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=2.52744197845459,disc loss=1.2500677108764648, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=2.3661699295043945,disc loss=1.1718088388442993, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=2.1186037063598633,disc loss=1.456166386604309, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=2.099031448364258,disc loss=1.1798720359802246, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=2.277880907058716,disc loss=1.4660773277282715, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=2.325749397277832,disc loss=1.2595075368881226, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=2.1091763973236084,disc loss=1.2679060697555542, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=2.1152584552764893,disc loss=1.336676001548767, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=2.2514848709106445,disc loss=1.137879729270935, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=2.443040609359741,disc loss=1.3418654203414917, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=1.8155884742736816,disc loss=1.4220554828643799, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=1.8318305015563965,disc loss=1.218349575996399, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=1.9497528076171875,disc loss=1.242331862449646, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=2.0220413208007812,disc loss=1.2860366106033325, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=2.120777130126953,disc loss=1.101241111755371, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=1.8345712423324585,disc loss=1.2564362287521362, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=1.8932448625564575,disc loss=1.3761054277420044, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=2.046532392501831,disc loss=1.2074583768844604, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=1.8729828596115112,disc loss=1.188533902168274, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=1.8488459587097168,disc loss=1.2607123851776123, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=2.076573371887207,disc loss=1.1451785564422607, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=2.0116970539093018,disc loss=1.0639266967773438, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=2.228766441345215,disc loss=1.250020980834961, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=2.00736665725708,disc loss=1.2190461158752441, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=2.0943641662597656,disc loss=1.2655668258666992, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=1.98103928565979,disc loss=1.0637255907058716, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=2.0701193809509277,disc loss=1.0795587301254272, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=2.178966999053955,disc loss=1.2433841228485107, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=2.0292859077453613,disc loss=1.143090844154358, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=2.3258070945739746,disc loss=1.1046854257583618, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=2.195889711380005,disc loss=0.9712187647819519, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=2.1659557819366455,disc loss=1.1097795963287354, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=2.274359941482544,disc loss=1.00846266746521, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=2.345759391784668,disc loss=0.9487013220787048, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=2.6105618476867676,disc loss=0.9151279330253601, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=2.601325750350952,disc loss=1.0359941720962524, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=2.3985342979431152,disc loss=1.032970905303955, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=2.739029884338379,disc loss=1.1318165063858032, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=2.277958869934082,disc loss=1.0910195112228394, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=2.4978015422821045,disc loss=0.9023224115371704, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=2.765397310256958,disc loss=0.9427819848060608, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=2.6724538803100586,disc loss=1.0152130126953125, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=2.5935111045837402,disc loss=1.0928518772125244, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=2.4851303100585938,disc loss=1.1131073236465454, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=2.4207260608673096,disc loss=1.0279152393341064, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=2.6291654109954834,disc loss=1.0305947065353394, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=2.752509593963623,disc loss=0.8858292698860168, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=2.7128803730010986,disc loss=1.0411564111709595, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=2.410301446914673,disc loss=1.0403945446014404, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=2.681765556335449,disc loss=0.8302094340324402, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=2.3722288608551025,disc loss=1.1180355548858643, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=2.8307008743286133,disc loss=1.009017825126648, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=2.762047052383423,disc loss=1.1242331266403198, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=2.687049388885498,disc loss=1.0967869758605957, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=2.6718623638153076,disc loss=1.1124904155731201, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=2.607099771499634,disc loss=0.9624332785606384, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=2.5988168716430664,disc loss=1.0487163066864014, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=2.4888179302215576,disc loss=1.1473567485809326, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=2.7394421100616455,disc loss=0.8950936198234558, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=2.9562206268310547,disc loss=0.8849523067474365, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=2.719275951385498,disc loss=1.1456940174102783, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=2.5949654579162598,disc loss=1.071044683456421, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=2.707625389099121,disc loss=0.920871913433075, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=2.5859177112579346,disc loss=1.057651162147522, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=2.5794050693511963,disc loss=0.9654040932655334, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=2.5842161178588867,disc loss=0.9775635004043579, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=2.6722006797790527,disc loss=0.9315253496170044, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=2.580622911453247,disc loss=1.058408260345459, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=2.5654067993164062,disc loss=0.9962666034698486, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=2.5401649475097656,disc loss=0.9674667119979858, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=2.7306363582611084,disc loss=1.028594732284546, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=2.5504331588745117,disc loss=0.9136354327201843, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=2.52781081199646,disc loss=0.8627097010612488, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=2.619708776473999,disc loss=0.9232080578804016, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=2.6850578784942627,disc loss=0.9292919635772705, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=2.5569326877593994,disc loss=0.93828946352005, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=2.6030447483062744,disc loss=0.9699175357818604, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=2.68556809425354,disc loss=1.0152583122253418, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=2.76226544380188,disc loss=0.9151616096496582, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=2.612734079360962,disc loss=0.9061092734336853, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=2.7764129638671875,disc loss=0.8318957686424255, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=2.8297064304351807,disc loss=0.8739913105964661, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=2.684068441390991,disc loss=0.8238673210144043, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=2.745790958404541,disc loss=0.8312433362007141, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=2.79667329788208,disc loss=0.8639707565307617, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=2.941730499267578,disc loss=0.9196134805679321, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=2.8636646270751953,disc loss=0.7909742593765259, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=2.771949529647827,disc loss=0.9026902318000793, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=2.723005771636963,disc loss=0.7385061383247375, {hms_string(epoch_elapsed)}
# Training time: 0:30:25.88

# %%
for i in range(1496):
  if training_data[i].shape != (96,96,3):
    print(i)
# Out:
# 601
# 1431

# %%
training_data[1431].shape
# Out:
# (96, 96, 4)

# %%
plt.imshow(training_data[601])

# %%
plt.imshow(training_data[1431])

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-a40b0209e0d9> in <module>()
# ----> 1 save_images(1,1)
#
# <ipython-input-30-0bebbd1cc017> in save_images(cnt, noise)
#     154       255, dtype=np.uint8)
#     155
# --> 156   generated_images = generator.predict(noise)
#     157
#     158   generated_images = 0.5 * generated_images + 0.5
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_shape.py in __getitem__(self, key)
#     900       else:
#     901         if self._v2_behavior:
# --> 902           return self._dims[key].value
#     903         else:
#     904           return self._dims[key]
#
# IndexError: list index out of range
